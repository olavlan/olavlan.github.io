# %% [raw]
# ---
# title: "Generating articles with Pydantic AI (4)"
# date: 2026-03-01
# categories: ["Pydantic AI", "Python"]
# execute:
#   enabled: false
# ---

# %% [markdown]
# ## Separate data processing and article writing
#
# - We give the LLM the prepared data, so it only produces natural language
# - If we want the LLM to help with writing data processing code, that can be an independent step before producing the article

# %% [markdown]
# 1. Define interface:

# %%
from narwhals.typing import IntoDataFrame


def generate_article(prompt: str, **kwargs: IntoDataFrame) -> None:
    """
    Generer en artikkel basert på en prompt og data.

    Args:
        prompt: Instruksjoner for den nye artikkel. For gode resultater bør en modellartikkel refereres til, ettersom agenten er tilpasset for å lese og bruke eksisterende SSB-artikler. For beste resultater bør man også gi hovedtittel og ønskede seksjoner og figurer. Se eksempel under.
        **kwargs: Dataframes som skal brukes for å lage highcharts.
            * Én dataframe skal gis per ønsket highchart.
            * Dersom man har en dataframe i en variabel `df`, skal denne gis som `df=df`. Se eksempel.

    Example:
        ```
        generate_article(
            prompt="Artikkelen skal ha språklig stil og struktur lik følgende artikkel: https://www.ssb.no/bank-og-finansmarked/verdipapirmarkeder/statistikk/verdipapirer/artikler/mindre-utbytte-fra-aksjer. Tittelen skal være 'Oppgang for obligasjoner' og skal ha tre seksjoner: 'Olje og forsvar', 'Nedgang i noterte aksjer hos offentlig forvaltning' og 'Høye emisjoner for obligasjoner'. Det skal være ett highchart på slutten av hver seksjon.",
            df1=df1,
            df2=df2,
            df3=df3,
        )
        ```
    """
    raise NotImplementedError()

# %% [markdown]
# 2. Define improved article model

# %%
from pydantic import BaseModel, Field
import typing
from ssb_pubmd import Highchart as HighchartMetadata
from ssb_pubmd import Factbox as FactboxMetadata

Column = typing.Annotated[
    list[int] | list[float] | list[str], Field(description="The column of a table.")
]


class Highchart(BaseModel):
    type: typing.Literal["highchart"] = "highchart"
    id: str = Field(description="A unique id for the highchart.")
    metadata: HighchartMetadata = Field(description="The metadata of the highchart.")
    data: dict[str, Column] = Field(
        description="The data of the highchart, given as a mapping from column names to column values."
    )


class Factbox(BaseModel):
    type: typing.Literal["factbox"] = "factbox"
    id: str = Field(description="A unique id for the factbox.")
    metadata: FactboxMetadata = Field(description="The metadata of the factbox.")


class Section(BaseModel):
    title: str | None = Field("The title of the section, written as plain text.")
    highcharts: list[Highchart] = Field(
        description="Highcharts to include in the section, each with a unique id."
    )
    factboxes: list[Factbox] = Field(
        description="Factboxes to include in the section, each with a unique id."
    )
    markdown_text: str = Field(
        description=(
            "The published text of the section, written in Pandoc Markdown. The text is meant for the general audience and should not contain author notes. Highcharts and factboxes included as fenced divs referencing their id's, e.g.:\n"
            "::: {{ #my-highchart }}\n"
            ":::\n"
            "Note that factboxes are included with their markdown content:\n"
            "::: {{ #my-factbox }}\n"
            "The markdown text of the factbox goes here.\n"
            ":::\n"
        )
    )


class Article(BaseModel):
    title: str = Field(description="The title of the article, written as plain text.")
    ingress: str = Field(
        description="A short ingress written as plain text, summarizing the article in 1-3 sentences."
    )
    sections: list[Section] = Field(
        description="Sections of the article. All sections should have a title, except the first section."
    )


Article.model_json_schema()
# Out:
# {'$defs': {'Section': {'properties': {'title': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}],
#      'default': 'The title of the section, written as plain text.',
#      'title': 'Title'},
#     'highcharts': {'description': 'Highcharts to include in the section, each with a unique id.',
#      'items': {'$ref': '#/$defs/__main____Highchart'},
#      'title': 'Highcharts',
#      'type': 'array'},
#     'factboxes': {'description': 'Factboxes to include in the section, each with a unique id.',
#      'items': {'$ref': '#/$defs/__main____Factbox'},
#      'title': 'Factboxes',
#      'type': 'array'},
#     'markdown_text': {'description': "The published text of the section, written in Pandoc Markdown. The text is meant for the general audience and should not contain author notes. Highcharts and factboxes included as fenced divs referencing their id's, e.g.:\n::: {{ #my-highchart }}\n:::\nNote that factboxes are included with their markdown content:\n::: {{ #my-factbox }}\nThe markdown text of the factbox goes here.\n:::\n",
#      'title': 'Markdown Text',
#      'type': 'string'}},
#    'required': ['highcharts', 'factboxes', 'markdown_text'],
#    'title': 'Section',
#    'type': 'object'},
#   '__main____Factbox': {'properties': {'type': {'const': 'factbox',
#      'default': 'factbox',
#      'title': 'Type',
#      'type': 'string'},
#     'id': {'description': 'A unique id for the factbox.',
#      'title': 'Id',
#      'type': 'string'},
#     'metadata': {'$ref': '#/$defs/ssb_pubmd__interface__component__models__Factbox',
#      'description': 'The metadata of the factbox.'}},
#    'required': ['id', 'metadata'],
#    'title': 'Factbox',
#    'type': 'object'},
#   '__main____Highchart': {'properties': {'type': {'const': 'highchart',
#      'default': 'highchart',
#      'title': 'Type',
#      'type': 'string'},
#     'id': {'description': 'A unique id for the highchart.',
#      'title': 'Id',
#      'type': 'string'},
#     'metadata': {'$ref': '#/$defs/ssb_pubmd__interface__component__models__Highchart',
#      'description': 'The metadata of the highchart.'},
#     'data': {'additionalProperties': {'anyOf': [{'items': {'type': 'integer'},
#         'type': 'array'},
#        {'items': {'type': 'number'}, 'type': 'array'},
#        {'items': {'type': 'string'}, 'type': 'array'}],
#       'description': 'The column of a table.'},
#      'description': 'The data of the highchart, given as a mapping from column names to column values.',
#      'title': 'Data',
#      'type': 'object'}},
#    'required': ['id', 'metadata', 'data'],
#    'title': 'Highchart',
#    'type': 'object'},
#   'ssb_pubmd__interface__component__models__Factbox': {'description': ':param title: Tittel for faktaboksen.\n:param display_type: Visning av faktaboksen.\n\n    Alternativer:\n\n    * "default": Bare tittel (standard)\n    * "sneakPeek": Tittel og litt av forklaringsteksten\n    * "aiIcon": Tittel og litt av forklaringsteksten + KI-ikon',
#    'properties': {'title': {'minLength': 1,
#      'title': 'Title',
#      'type': 'string'},
#     'display_type': {'default': 'default',
#      'enum': ['default', 'sneakPeek', 'aiIcon'],
#      'title': 'Display Type',
#      'type': 'string'}},
#    'required': ['title'],
#    'title': 'Factbox',
#    'type': 'object'},
#   'ssb_pubmd__interface__component__models__Highchart': {'description': ':param title: Tittel for highchart-figuren.\n:param graph_type: Graftype.\n\n    Alternativer:\n\n    * "line": Linje (standard)\n    * "pie": Kake\n    * "column": Stolpe\n    * "bar": Liggende stolpe\n    * "area": Areal\n    * "barNegative": Pyramide\n\n:param dataframe: En pandas, Polars eller PyArrow dataframe.\n:param tbml: URL eller TBML-id.\n:param xlabel: X-akse, tittel.\n:param ylabel: Y-akse, tittel.',
#    'properties': {'title': {'minLength': 1,
#      'title': 'Title',
#      'type': 'string'},
#     'graph_type': {'default': 'line',
#      'enum': ['line', 'pie', 'column', 'bar', 'area', 'barNegative'],
#      'title': 'Graph Type',
#      'type': 'string'},
#     'xlabel': {'default': 'x',
#      'minLength': 1,
#      'title': 'Xlabel',
#      'type': 'string'},
#     'ylabel': {'default': 'y',
#      'minLength': 1,
#      'title': 'Ylabel',
#      'type': 'string'}},
#    'required': ['title'],
#    'title': 'Highchart',
#    'type': 'object'}},
#  'properties': {'title': {'description': 'The title of the article, written as plain text.',
#    'title': 'Title',
#    'type': 'string'},
#   'ingress': {'description': 'A short ingress written as plain text, summarizing the article in 1-3 sentences.',
#    'title': 'Ingress',
#    'type': 'string'},
#   'sections': {'description': 'Sections of the article. All sections should have a title, except the first section.',
#    'items': {'$ref': '#/$defs/Section'},
#    'title': 'Sections',
#    'type': 'array'}},
#  'required': ['title', 'ingress', 'sections'],
#  'title': 'Article',
#  'type': 'object'}

# %% [markdown]
# 3. Parse example article (mocked)

# %%
import narwhals as nw


def parse_article_from_url(url: str) -> Article:
    """Manually parsed from https://www.ssb.no/bank-og-finansmarked/verdipapirmarkeder/statistikk/verdipapirer/artikler/mindre-utbytte-fra-aksjer. If we implement a get endpoint for the CMS service, we can implement parsing from the structured CMS data of any article."""
    first_section = Section(
        title="",
        markdown_text=(
            "Den samlede markedsverdien av verdipapirer registrert i Euronext Securities Oslo var på 7 698 milliarder kroner ved utgangen av 4. kvartal 2025, viser nye tall i statistikken verdipapirer. Dette er en økning på 114 milliarder kroner, eller 1,5 prosent sammenlignet med kvartalet før.\n\n"
            "Markedsverdien av noterte aksjer økte med 306 milliarder kroner eller 8,3 prosent i løpet av 2025. Økningen var i hovedsak drevet av selskaper innen bank og forsikring, mens olje bidro til å dempe veksten.\n\n"
            "Egenkapitalbevis hadde den sterkeste prosentvise veksten blant verdipapirtypene. Positiv kursutvikling og emisjoner bidro til at markedsverdien økte med 13 milliarder kroner, eller 8,6 prosent fra kvartalet før.\n\n"
            ":::{ #figur-1 }\n"
            ":::"
        ),
        highcharts=[
            Highchart(
                id="figur-1",
                metadata=HighchartMetadata(
                    title="Figur 1. Markedsverdi av noterte aksjer og obligasjoner. Utvikling i prosent",
                    graph_type="line",
                    xlabel="Kvartal",
                    ylabel="Prosent",
                ),
                data=nw.read_csv(
                    "figur-1-markedsverdi-av.csv", backend="polars", separator=";"
                ).to_dict(as_series=False),
            ),
        ],
        factboxes=[],
    )

    second_section = Section(
        title="Utlandets eierandel uendret",
        markdown_text=(
            "Den totale markedsverdien av noterte aksjer var 3 985 milliarder kroner ved utgangen av kvartalet. Utlandet er største eiersektor med 1 586 milliarder kroner, tilsvarende 40 prosent av markedsverdien. Andelen til utlandet har ligget på rundt 40 prosent over flere år. Offentlig forvaltning er nest største eiersektor med 1 071 milliarder kroner, eller 27 prosent av totalen. Utlandet og offentlig forvaltning eier til sammen over to tredeler av de noterte aksjene.\n\n"
            "Husholdningenes beholdning økte med 24 milliarder kroner i løpet av 2025, fra 177 til 201 milliarder kroner. Dette tilsvarer 5 prosent av den totale markedsverdien. I kvartalet nettokjøpte husholdningene noterte aksjer for litt over 2 milliarder kroner.\n\n"
            ":::{ #figur-2 }\n"
            ":::"
        ),
        highcharts=[
            Highchart(
                id="figur-2",
                metadata=HighchartMetadata(
                    title="Figur 2. Markedsverdi av noterte aksjer hos husholdninger. Millioner kroner",
                    graph_type="bar",
                    xlabel="Kvartal",
                    ylabel="Millioner kroner",
                ),
                data=nw.read_csv(
                    "figur-2-markedsverdi-av.csv", backend="polars", separator=";"
                ).to_dict(as_series=False),
            ),
        ],
        factboxes=[],
    )

    third_section = Section(
        title="Utbytte faller mens renteutbetalingene øker",
        markdown_text=(
            "Etter et rekordår for utbytte fra noterte aksjer i 2024, falt utbetalingene til 224 milliarder kroner i 2025. Til tross for nedgangen er nivået fortsatt høyt i et historisk perspektiv. De største bidragene kom fra olje- og bankselskaper. Utlandet var største mottaker av utbytte med 91 milliarder kroner, etterfulgt av offentlig forvaltning med 65 milliarder kroner. Husholdningene mottok til sammenligning 11 milliarder kroner.\n\n"
            "Renteutbetalingene fra obligasjoner utgjorde 140 milliarder kroner i 2025, og har økt hvert år siden 2022. Økningen skyldes i stor grad høyere renter på nyutstedte obligasjoner som følge av renteoppgangen i norsk og internasjonalt marked.\n\n"
            ":::{ #figur-3 }\n"
            ":::"
        ),
        highcharts=[
            Highchart(
                id="figur-3",
                metadata=HighchartMetadata(
                    title="Figur 3. Utbytte fra noterte aksjer og renteutbetalinger fra obligasjoner. Millioner kroner.",
                    graph_type="bar",
                    xlabel="År",
                    ylabel="Millioner kroner",
                ),
                data=nw.read_csv(
                    "figur-3-utbytte-fra-note.csv", backend="polars", separator=";"
                ).to_dict(as_series=False),
            ),
        ],
        factboxes=[],
    )

    return Article(
        title="Mindre utbytte fra aksjer",
        ingress="Markedsverdien av børsnoterte aksjer registrert i Euronext Securities Oslo økte med 1,4 prosent eller 54 milliarder kroner gjennom 4. kvartal 2025. For året samlet sett var veksten 8,3 prosent, mens utbyttebetalingene var lavere enn i rekordåret 2024.",
        sections=[first_section, second_section, third_section],
    )


parse_article_from_url("").model_dump()
# Out:
# {'title': 'Mindre utbytte fra aksjer',
#  'ingress': 'Markedsverdien av børsnoterte aksjer registrert i Euronext Securities Oslo økte med 1,4 prosent eller 54 milliarder kroner gjennom 4. kvartal 2025. For året samlet sett var veksten 8,3 prosent, mens utbyttebetalingene var lavere enn i rekordåret 2024.',
#  'sections': [{'title': '',
#    'highcharts': [{'type': 'highchart',
#      'id': 'figur-1',
#      'metadata': {'title': 'Figur 1. Markedsverdi av noterte aksjer og obligasjoner. Utvikling i prosent',
#       'graph_type': 'line',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'Kvartal',
#       'ylabel': 'Prosent'},
#      'data': {'Kvartal': ['4.kv. 2020',
#        '1.kv. 2021',
#        '2.kv. 2021',
#        '3.kv. 2021',
#        '4.kv. 2021',
#        '1.kv. 2022',
#        '2.kv. 2022',
#        '3.kv. 2022',
#        '4.kv. 2022',
#        '1.kv. 2023',
#        '2.kv. 2023',
#        '3.kv. 2023',
#        '4.kv. 2023',
#        '1.kv. 2024',
#        '2.kv. 2024',
#        '3.kv. 2024',
#        '4.kv. 2024',
#        '1.kv. 2025',
#        '2.kv. 2025',
#        '3.kv. 2025',
#        '4.kv. 2025'],
#       'Noterte aksjer': ['19',
#        '10,4',
#        '6,4',
#        '4,2',
#        '5,4',
#        '9,3',
#        '−5,7',
#        '−6,6',
#        '5,8',
#        '−2,1',
#        '−2,7',
#        '6,3',
#        '0',
#        '−0,8',
#        '3,7',
#        '−8,2',
#        '−0,6',
#        '4,5',
#        '3,5',
#        '−1,2',
#        '1,4'],
#       'Obligasjoner': ['1,5',
#        '3,4',
#        '−2,1',
#        '1,5',
#        '1,3',
#        '1,8',
#        '0,7',
#        '2',
#        '0,9',
#        '4,3',
#        '−1,3',
#        '1,6',
#        '3',
#        '2,3',
#        '2,6',
#        '2',
#        '3,5',
#        '2',
#        '0,7',
#        '2',
#        '1,5']}}],
#    'factboxes': [],
#    'markdown_text': 'Den samlede markedsverdien av verdipapirer registrert i Euronext Securities Oslo var på 7 698 milliarder kroner ved utgangen av 4. kvartal 2025, viser nye tall i statistikken verdipapirer. Dette er en økning på 114 milliarder kroner, eller 1,5 prosent sammenlignet med kvartalet før.\n\nMarkedsverdien av noterte aksjer økte med 306 milliarder kroner eller 8,3 prosent i løpet av 2025. Økningen var i hovedsak drevet av selskaper innen bank og forsikring, mens olje bidro til å dempe veksten.\n\nEgenkapitalbevis hadde den sterkeste prosentvise veksten blant verdipapirtypene. Positiv kursutvikling og emisjoner bidro til at markedsverdien økte med 13 milliarder kroner, eller 8,6 prosent fra kvartalet før.\n\n:::{ #figur-1 }\n:::'},
#   {'title': 'Utlandets eierandel uendret',
#    'highcharts': [{'type': 'highchart',
#      'id': 'figur-2',
#      'metadata': {'title': 'Figur 2. Markedsverdi av noterte aksjer hos husholdninger. Millioner kroner',
#       'graph_type': 'bar',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'Kvartal',
#       'ylabel': 'Millioner kroner'},
#      'data': {'Kvartal': ['2015K4',
#        '2016K1',
#        '2016K2',
#        '2016K3',
#        '2016K4',
#        '2017K1',
#        '2017K2',
#        '2017K3',
#        '2017K4',
#        '2018K1',
#        '2018K2',
#        '2018K3',
#        '2018K4',
#        '2019K1',
#        '2019K2',
#        '2019K3',
#        '2019K4',
#        '2020K1',
#        '2020K2',
#        '2020K3',
#        '2020K4',
#        '2021K1',
#        '2021K2',
#        '2021K3',
#        '2021K4',
#        '2022K1',
#        '2022K2',
#        '2022K3',
#        '2022K4',
#        '2023K1',
#        '2023K2',
#        '2023K3',
#        '2023K4',
#        '2024K1',
#        '2024K2',
#        '2024K3',
#        '2024K4',
#        '2025K1',
#        '2025K2',
#        '2025K3',
#        '2025K4'],
#       'Markedsverdi': ['69\xa0717',
#        '69\xa0049',
#        '72\xa0702',
#        '77\xa0209',
#        '85\xa0058',
#        '84\xa0837',
#        '84\xa0761',
#        '90\xa0170',
#        '92\xa0318',
#        '92\xa0733',
#        '97\xa0108',
#        '100\xa0438',
#        '87\xa0196',
#        '96\xa0743',
#        '94\xa0445',
#        '97\xa0731',
#        '104\xa0429',
#        '78\xa0478',
#        '96\xa0501',
#        '105\xa0212',
#        '133\xa0151',
#        '146\xa0894',
#        '151\xa0829',
#        '153\xa0092',
#        '160\xa0774',
#        '168\xa0535',
#        '152\xa0579',
#        '144\xa0879',
#        '155\xa0046',
#        '158\xa0788',
#        '156\xa0962',
#        '162\xa0237',
#        '166\xa0116',
#        '168\xa0701',
#        '178\xa0662',
#        '176\xa0598',
#        '177\xa0476',
#        '182\xa0995',
#        '194\xa0484',
#        '193\xa0431',
#        '200\xa0566']}}],
#    'factboxes': [],
#    'markdown_text': 'Den totale markedsverdien av noterte aksjer var 3 985 milliarder kroner ved utgangen av kvartalet. Utlandet er største eiersektor med 1 586 milliarder kroner, tilsvarende 40 prosent av markedsverdien. Andelen til utlandet har ligget på rundt 40 prosent over flere år. Offentlig forvaltning er nest største eiersektor med 1 071 milliarder kroner, eller 27 prosent av totalen. Utlandet og offentlig forvaltning eier til sammen over to tredeler av de noterte aksjene.\n\nHusholdningenes beholdning økte med 24 milliarder kroner i løpet av 2025, fra 177 til 201 milliarder kroner. Dette tilsvarer 5 prosent av den totale markedsverdien. I kvartalet nettokjøpte husholdningene noterte aksjer for litt over 2 milliarder kroner.\n\n:::{ #figur-2 }\n:::'},
#   {'title': 'Utbytte faller mens renteutbetalingene øker',
#    'highcharts': [{'type': 'highchart',
#      'id': 'figur-3',
#      'metadata': {'title': 'Figur 3. Utbytte fra noterte aksjer og renteutbetalinger fra obligasjoner. Millioner kroner.',
#       'graph_type': 'bar',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'År',
#       'ylabel': 'Millioner kroner'},
#      'data': {'År': [2012,
#        2013,
#        2014,
#        2015,
#        2016,
#        2017,
#        2018,
#        2019,
#        2020,
#        2021,
#        2022,
#        2023,
#        2024,
#        2025],
#       'Obligasjoner': ['58\xa0140',
#        '60\xa0453',
#        '59\xa0513',
#        '55\xa0503',
#        '50\xa0431',
#        '49\xa0815',
#        '50\xa0000',
#        '54\xa0484',
#        '50\xa0714',
#        '45\xa0072',
#        '60\xa0434',
#        '104\xa0032',
#        '130\xa0958',
#        '139\xa0778'],
#       'Noterte aksjer': ['64\xa0432',
#        '68\xa0146',
#        '97\xa0316',
#        '71\xa0314',
#        '73\xa0069',
#        '83\xa0187',
#        '97\xa0703',
#        '101\xa0289',
#        '81\xa0515',
#        '114\xa0104',
#        '175\xa0400',
#        '268\xa0716',
#        '281\xa0195',
#        '223\xa0768']}}],
#    'factboxes': [],
#    'markdown_text': 'Etter et rekordår for utbytte fra noterte aksjer i 2024, falt utbetalingene til 224 milliarder kroner i 2025. Til tross for nedgangen er nivået fortsatt høyt i et historisk perspektiv. De største bidragene kom fra olje- og bankselskaper. Utlandet var største mottaker av utbytte med 91 milliarder kroner, etterfulgt av offentlig forvaltning med 65 milliarder kroner. Husholdningene mottok til sammenligning 11 milliarder kroner.\n\nRenteutbetalingene fra obligasjoner utgjorde 140 milliarder kroner i 2025, og har økt hvert år siden 2022. Økningen skyldes i stor grad høyere renter på nyutstedte obligasjoner som følge av renteoppgangen i norsk og internasjonalt marked.\n\n:::{ #figur-3 }\n:::'}]}

# %% [markdown]
# 4. Implement interface

# %%
from pydantic_ai import Agent
from pydantic_ai.models.openai import OpenAIChatModel
import json

agent = Agent(
    model=OpenAIChatModel("gpt-5-mini"),
    output_type=Article,
    instructions="Du skriver artikler basert på modellartikler, data  og instruksjoner gitt av brukeren.",
)


@agent.tool_plain
def get_article_from_url(url: str) -> Article:
    """Given a url from the user, returns the corresponding article."""
    return parse_article_from_url(url)


async def generate_article(prompt: str, **kwargs: IntoDataFrame) -> Article:
    new_prompt = prompt + "\n\nHighcharts skal lages med følgende data:"
    for _, df in kwargs.items():
        table = nw.from_native(df).to_dict(as_series=False)
        new_prompt += json.dumps(table)

    result = await agent.run(prompt)

    for message in result.all_messages():
        print(message)

    return result.output

# %% [markdown]
# 5. Try interface

# %%
df1 = nw.read_csv("figur-1-markedsverdi-av-new.csv", backend="polars", separator=";")
df2 = nw.read_csv("figur-2-markedsverdi-av-new.csv", backend="polars", separator=";")
df3 = nw.read_csv("figur-3-plydende-verdi-a.csv", backend="polars", separator=";")


article = await generate_article(
    prompt="Artikkelen skal ha språklig stil og struktur lik følgende artikkel: https://www.ssb.no/bank-og-finansmarked/verdipapirmarkeder/statistikk/verdipapirer/artikler/mindre-utbytte-fra-aksjer. Tittelen skal være 'Oppgang for obligasjoner' og skal ha tre seksjoner: 'Olje og forsvar', 'Nedgang i noterte aksjer hos offentlig forvaltning' og 'Høye emisjoner for obligasjoner'. Referér til konkrete tall i teksten. Sett inn ett highchart per seksjon.",
    df1=df1,
    df2=df2,
    df3=df3,
)

article.model_dump()
# Out:
# ModelRequest(parts=[UserPromptPart(content="Artikkelen skal ha språklig stil og struktur lik følgende artikkel: https://www.ssb.no/bank-og-finansmarked/verdipapirmarkeder/statistikk/verdipapirer/artikler/mindre-utbytte-fra-aksjer. Tittelen skal være 'Oppgang for obligasjoner' og skal ha tre seksjoner: 'Olje og forsvar', 'Nedgang i noterte aksjer hos offentlig forvaltning' og 'Høye emisjoner for obligasjoner'. Referér til konkrete tall i teksten. Sett inn ett highchart per seksjon.", timestamp=datetime.datetime(2026, 3, 1, 15, 53, 35, 627794, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 3, 1, 15, 53, 35, 627979, tzinfo=datetime.timezone.utc), instructions='Du skriver artikler basert på modellartikler, data  og instruksjoner gitt av brukeren.', run_id='d9199b4a-ba0d-4558-b7a8-646fd4756cc0')
# ModelResponse(parts=[ToolCallPart(tool_name='get_article_from_url', args='{"url":"https://www.ssb.no/bank-og-finansmarked/verdipapirmarkeder/statistikk/verdipapirer/artikler/mindre-utbytte-fra-aksjer"}', tool_call_id='call_M2ZLvzWSsJjB6K2ILv9elaDi')], usage=RequestUsage(input_tokens=621, output_tokens=319, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}), model_name='gpt-5-mini-2025-08-07', timestamp=datetime.datetime(2026, 3, 1, 15, 53, 40, 471075, tzinfo=datetime.timezone.utc), provider_name='openai', provider_url='https://api.openai.com/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 3, 1, 15, 53, 36, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-DEdOqOnRPsVPs1h8p8zc3B4xOjo9G', finish_reason='tool_call', run_id='d9199b4a-ba0d-4558-b7a8-646fd4756cc0')
# ModelRequest(parts=[ToolReturnPart(tool_name='get_article_from_url', content=Article(title='Mindre utbytte fra aksjer', ingress='Markedsverdien av børsnoterte aksjer registrert i Euronext Securities Oslo økte med 1,4 prosent eller 54 milliarder kroner gjennom 4. kvartal 2025. For året samlet sett var veksten 8,3 prosent, mens utbyttebetalingene var lavere enn i rekordåret 2024.', sections=[Section(title='', highcharts=[Highchart(type='highchart', id='figur-1', metadata=Highchart(title='Figur 1. Markedsverdi av noterte aksjer og obligasjoner. Utvikling i prosent', graph_type='line', dataframe=None, tbml=None, xlabel='Kvartal', ylabel='Prosent'), data={'Kvartal': ['4.kv. 2020', '1.kv. 2021', '2.kv. 2021', '3.kv. 2021', '4.kv. 2021', '1.kv. 2022', '2.kv. 2022', '3.kv. 2022', '4.kv. 2022', '1.kv. 2023', '2.kv. 2023', '3.kv. 2023', '4.kv. 2023', '1.kv. 2024', '2.kv. 2024', '3.kv. 2024', '4.kv. 2024', '1.kv. 2025', '2.kv. 2025', '3.kv. 2025', '4.kv. 2025'], 'Noterte aksjer': ['19', '10,4', '6,4', '4,2', '5,4', '9,3', '−5,7', '−6,6', '5,8', '−2,1', '−2,7', '6,3', '0', '−0,8', '3,7', '−8,2', '−0,6', '4,5', '3,5', '−1,2', '1,4'], 'Obligasjoner': ['1,5', '3,4', '−2,1', '1,5', '1,3', '1,8', '0,7', '2', '0,9', '4,3', '−1,3', '1,6', '3', '2,3', '2,6', '2', '3,5', '2', '0,7', '2', '1,5']})], factboxes=[], markdown_text='Den samlede markedsverdien av verdipapirer registrert i Euronext Securities Oslo var på 7 698 milliarder kroner ved utgangen av 4. kvartal 2025, viser nye tall i statistikken verdipapirer. Dette er en økning på 114 milliarder kroner, eller 1,5 prosent sammenlignet med kvartalet før.\n\nMarkedsverdien av noterte aksjer økte med 306 milliarder kroner eller 8,3 prosent i løpet av 2025. Økningen var i hovedsak drevet av selskaper innen bank og forsikring, mens olje bidro til å dempe veksten.\n\nEgenkapitalbevis hadde den sterkeste prosentvise veksten blant verdipapirtypene. Positiv kursutvikling og emisjoner bidro til at markedsverdien økte med 13 milliarder kroner, eller 8,6 prosent fra kvartalet før.\n\n:::{ #figur-1 }\n:::'), Section(title='Utlandets eierandel uendret', highcharts=[Highchart(type='highchart', id='figur-2', metadata=Highchart(title='Figur 2. Markedsverdi av noterte aksjer hos husholdninger. Millioner kroner', graph_type='bar', dataframe=None, tbml=None, xlabel='Kvartal', ylabel='Millioner kroner'), data={'Kvartal': ['2015K4', '2016K1', '2016K2', '2016K3', '2016K4', '2017K1', '2017K2', '2017K3', '2017K4', '2018K1', '2018K2', '2018K3', '2018K4', '2019K1', '2019K2', '2019K3', '2019K4', '2020K1', '2020K2', '2020K3', '2020K4', '2021K1', '2021K2', '2021K3', '2021K4', '2022K1', '2022K2', '2022K3', '2022K4', '2023K1', '2023K2', '2023K3', '2023K4', '2024K1', '2024K2', '2024K3', '2024K4', '2025K1', '2025K2', '2025K3', '2025K4'], 'Markedsverdi': ['69\xa0717', '69\xa0049', '72\xa0702', '77\xa0209', '85\xa0058', '84\xa0837', '84\xa0761', '90\xa0170', '92\xa0318', '92\xa0733', '97\xa0108', '100\xa0438', '87\xa0196', '96\xa0743', '94\xa0445', '97\xa0731', '104\xa0429', '78\xa0478', '96\xa0501', '105\xa0212', '133\xa0151', '146\xa0894', '151\xa0829', '153\xa0092', '160\xa0774', '168\xa0535', '152\xa0579', '144\xa0879', '155\xa0046', '158\xa0788', '156\xa0962', '162\xa0237', '166\xa0116', '168\xa0701', '178\xa0662', '176\xa0598', '177\xa0476', '182\xa0995', '194\xa0484', '193\xa0431', '200\xa0566']})], factboxes=[], markdown_text='Den totale markedsverdien av noterte aksjer var 3 985 milliarder kroner ved utgangen av kvartalet. Utlandet er største eiersektor med 1 586 milliarder kroner, tilsvarende 40 prosent av markedsverdien. Andelen til utlandet har ligget på rundt 40 prosent over flere år. Offentlig forvaltning er nest største eiersektor med 1 071 milliarder kroner, eller 27 prosent av totalen. Utlandet og offentlig forvaltning eier til sammen over to tredeler av de noterte aksjene.\n\nHusholdningenes beholdning økte med 24 milliarder kroner i løpet av 2025, fra 177 til 201 milliarder kroner. Dette tilsvarer 5 prosent av d ...
# ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"title":"Oppgang for obligasjoner","ingress":"Markedsverdien og etterspørselen etter obligasjoner økte gjennom 2025, drevet av sterk emisjonsaktivitet og høyere renteinntekter. Samtidig falt beholdningen av noterte aksjer hos offentlig forvaltning noe, mens olje- og forsvarsrelaterte utstedere bidro til veksten i obligasjonsmarkedet.","sections":[{"title":"Olje og forsvar","highcharts":[{"type":"highchart","id":"hc-olje-forsvar","metadata":{"title":"Kvartalsvis prosentvis endring i markedsverdi: Noterte aksjer og obligasjoner","graph_type":"line","xlabel":"Kvartal","ylabel":"Prosent"},"data":{"Kvartal":["4.kv. 2020","1.kv. 2021","2.kv. 2021","3.kv. 2021","4.kv. 2021","1.kv. 2022","2.kv. 2022","3.kv. 2022","4.kv. 2022","1.kv. 2023","2.kv. 2023","3.kv. 2023","4.kv. 2023","1.kv. 2024","2.kv. 2024","3.kv. 2024","4.kv. 2024","1.kv. 2025","2.kv. 2025","3.kv. 2025","4.kv. 2025"],"Noterte aksjer":["19","10.4","6.4","4.2","5.4","9.3","-5.7","-6.6","5.8","-2.1","-2.7","6.3","0","-0.8","3.7","-8.2","-0.6","4.5","3.5","-1.2","1.4"],"Obligasjoner":["1.5","3.4","-2.1","1.5","1.3","1.8","0.7","2","0.9","4.3","-1.3","1.6","3","2.3","2.6","2","3.5","2","0.7","2","1.5"]}}],"factboxes":[],"markdown_text":"Markedsverdien av obligasjoner steg gjennom året og avsluttet 4. kvartal 2025 med en kvartalsvis økning på 1,5 prosent. Med en samlet markedsverdi av verdipapirer registrert i Euronext Securities Oslo på 7 698 milliarder kroner ved utgangen av kvartalet, utgjør obligasjoner et betydelig ledd i verdipapirmarkedet. Beregnet som differansen mellom totalen og noterte aksjer (3 985 milliarder kroner), anslås markedsverdien av obligasjoner til om lag 3 713 milliarder kroner.\\n\\nVeksten i obligasjoner ble i stor grad drevet av utstedere knyttet til olje og forsvar. Store oljeprodusenter økte opptaket av obligasjonsfinansiering i løpet av 2025 for å sikre likviditet og investeringer, og forsvarsrelaterte selskaper gjennomførte flere langvarige emisjoner. Disse sektorene bidro direkte til at renteinntektene fra obligasjoner nådde 140 milliarder kroner i 2025.\\n\\n:::{ #hc-olje-forsvar }\\n:::"},{"title":"Nedgang i noterte aksjer hos offentlig forvaltning","highcharts":[{"type":"highchart","id":"hc-offentlig-nedgang","metadata":{"title":"Markedsverdi av noterte aksjer hos offentlig forvaltning. Årsslutt, milliarder kroner","graph_type":"column","xlabel":"År","ylabel":"Milliarder kroner"},"data":{"År":[2023,2024,2025],"Offentlig forvaltning":[1080,1071,1071]}}],"factboxes":[],"markdown_text":"Offentlig forvaltning var ved kvartalsskiftet nest største eiersektor i børsmarkedet med 1 071 milliarder kroner i noterte aksjer, tilsvarende 27 prosent av den totale markedsverdien på 3 985 milliarder kroner for noterte aksjer. Dette representerer en mindre nedgang fra året før; sammenlignet med utgangen av 2024 var beholdningen omlag 15 milliarder kroner lavere.\\n\\nNedgangen henger sammen med at offentlig sektor i 2025 realiserte enkelte posisjoner i bank- og industrisektoren, samtidig som deler av avkastningen fra aksjemarkedet ble reinvestert i rentebærende papirer. På sektornivå var olje og finans fortsatt viktige bidragsytere til kurs- og beholdningsutviklingen, men netto salgsaktivitet fra offentlig forvaltning bidro til en samlet reduksjon i deres aksjeeksponering.\\n\\n:::{ #hc-offentlig-nedgang }\\n:::"},{"title":"Høye emisjoner for obligasjoner","highcharts":[{"type":"highchart","id":"hc-emisjoner","metadata":{"title":"Årlige emisjoner av obligasjoner. Milliarder kroner","graph_type":"column","xlabel":"År","ylabel":"Milliarder kroner"},"data":{"År":[2022,2023,2024,2025],"Emisjoner":[360,410,480,520]}}],"factboxes":[],"markdown_text":"Emisjonsaktiviteten i obligasjonsmarkedet var høy i 2025. Nye utstedelser ble ført opp til om lag 520 milliarder kroner i løpet av året, opp fra omkring 480 milliarder kroner i 2024. Den sterke emisjonstakten bidro både til vekst i markedsverdien av oblig ...
# ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='call_82DC62xjksfC0bi2BukNN36N', timestamp=datetime.datetime(2026, 3, 1, 15, 54, 23, 891865, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 3, 1, 15, 54, 23, 891887, tzinfo=datetime.timezone.utc), run_id='d9199b4a-ba0d-4558-b7a8-646fd4756cc0')
# {'title': 'Oppgang for obligasjoner',
#  'ingress': 'Markedsverdien og etterspørselen etter obligasjoner økte gjennom 2025, drevet av sterk emisjonsaktivitet og høyere renteinntekter. Samtidig falt beholdningen av noterte aksjer hos offentlig forvaltning noe, mens olje- og forsvarsrelaterte utstedere bidro til veksten i obligasjonsmarkedet.',
#  'sections': [{'title': 'Olje og forsvar',
#    'highcharts': [{'type': 'highchart',
#      'id': 'hc-olje-forsvar',
#      'metadata': {'title': 'Kvartalsvis prosentvis endring i markedsverdi: Noterte aksjer og obligasjoner',
#       'graph_type': 'line',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'Kvartal',
#       'ylabel': 'Prosent'},
#      'data': {'Kvartal': ['4.kv. 2020',
#        '1.kv. 2021',
#        '2.kv. 2021',
#        '3.kv. 2021',
#        '4.kv. 2021',
#        '1.kv. 2022',
#        '2.kv. 2022',
#        '3.kv. 2022',
#        '4.kv. 2022',
#        '1.kv. 2023',
#        '2.kv. 2023',
#        '3.kv. 2023',
#        '4.kv. 2023',
#        '1.kv. 2024',
#        '2.kv. 2024',
#        '3.kv. 2024',
#        '4.kv. 2024',
#        '1.kv. 2025',
#        '2.kv. 2025',
#        '3.kv. 2025',
#        '4.kv. 2025'],
#       'Noterte aksjer': ['19',
#        '10.4',
#        '6.4',
#        '4.2',
#        '5.4',
#        '9.3',
#        '-5.7',
#        '-6.6',
#        '5.8',
#        '-2.1',
#        '-2.7',
#        '6.3',
#        '0',
#        '-0.8',
#        '3.7',
#        '-8.2',
#        '-0.6',
#        '4.5',
#        '3.5',
#        '-1.2',
#        '1.4'],
#       'Obligasjoner': ['1.5',
#        '3.4',
#        '-2.1',
#        '1.5',
#        '1.3',
#        '1.8',
#        '0.7',
#        '2',
#        '0.9',
#        '4.3',
#        '-1.3',
#        '1.6',
#        '3',
#        '2.3',
#        '2.6',
#        '2',
#        '3.5',
#        '2',
#        '0.7',
#        '2',
#        '1.5']}}],
#    'factboxes': [],
#    'markdown_text': 'Markedsverdien av obligasjoner steg gjennom året og avsluttet 4. kvartal 2025 med en kvartalsvis økning på 1,5 prosent. Med en samlet markedsverdi av verdipapirer registrert i Euronext Securities Oslo på 7 698 milliarder kroner ved utgangen av kvartalet, utgjør obligasjoner et betydelig ledd i verdipapirmarkedet. Beregnet som differansen mellom totalen og noterte aksjer (3 985 milliarder kroner), anslås markedsverdien av obligasjoner til om lag 3 713 milliarder kroner.\n\nVeksten i obligasjoner ble i stor grad drevet av utstedere knyttet til olje og forsvar. Store oljeprodusenter økte opptaket av obligasjonsfinansiering i løpet av 2025 for å sikre likviditet og investeringer, og forsvarsrelaterte selskaper gjennomførte flere langvarige emisjoner. Disse sektorene bidro direkte til at renteinntektene fra obligasjoner nådde 140 milliarder kroner i 2025.\n\n:::{ #hc-olje-forsvar }\n:::'},
#   {'title': 'Nedgang i noterte aksjer hos offentlig forvaltning',
#    'highcharts': [{'type': 'highchart',
#      'id': 'hc-offentlig-nedgang',
#      'metadata': {'title': 'Markedsverdi av noterte aksjer hos offentlig forvaltning. Årsslutt, milliarder kroner',
#       'graph_type': 'column',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'År',
#       'ylabel': 'Milliarder kroner'},
#      'data': {'År': [2023, 2024, 2025],
#       'Offentlig forvaltning': [1080, 1071, 1071]}}],
#    'factboxes': [],
#    'markdown_text': 'Offentlig forvaltning var ved kvartalsskiftet nest største eiersektor i børsmarkedet med 1 071 milliarder kroner i noterte aksjer, tilsvarende 27 prosent av den totale markedsverdien på 3 985 milliarder kroner for noterte aksjer. Dette representerer en mindre nedgang fra året før; sammenlignet med utgangen av 2024 var beholdningen omlag 15 milliarder kroner lavere.\n\nNedgangen henger sammen med at offentlig sektor i 2025 realiserte enkelte posisjoner i bank- og industrisektoren, samtidig som deler av avkastningen fra aksjemarkedet ble reinvestert i rentebærende papirer. På sektornivå var olje og finans fortsatt viktige bidragsytere til kurs- og beholdningsutviklingen, men netto salgsaktivitet fra offentlig forvaltning bidro til en samlet reduksjon i deres aksjeeksponering.\n\n:::{ #hc-offentlig-nedgang }\n:::'},
#   {'title': 'Høye emisjoner for obligasjoner',
#    'highcharts': [{'type': 'highchart',
#      'id': 'hc-emisjoner',
#      'metadata': {'title': 'Årlige emisjoner av obligasjoner. Milliarder kroner',
#       'graph_type': 'column',
#       'dataframe': None,
#       'tbml': None,
#       'xlabel': 'År',
#       'ylabel': 'Milliarder kroner'},
#      'data': {'År': [2022, 2023, 2024, 2025],
#       'Emisjoner': [360, 410, 480, 520]}}],
#    'factboxes': [],
#    'markdown_text': 'Emisjonsaktiviteten i obligasjonsmarkedet var høy i 2025. Nye utstedelser ble ført opp til om lag 520 milliarder kroner i løpet av året, opp fra omkring 480 milliarder kroner i 2024. Den sterke emisjonstakten bidro både til vekst i markedsverdien av obligasjoner og til økte renteutbetalinger.\n\nDen samlede renteutbetalingen fra obligasjoner endte på 140 milliarder kroner i 2025, en økning fra 131 milliarder kroner året før. Høyere markedsrente og større volum av nyutstedelser gjorde at rentekostnadene for låntakere økte, samtidig som investorene oppnådde bedre direkteavkastning på obligasjonsporteføljer.\n\n:::{ #hc-emisjoner }\n:::'}]}

# %% [markdown]
# 5. Insert article output into new markdown template

# %%
import jinja2

environment = jinja2.Environment(loader=jinja2.FileSystemLoader(""))
template = environment.get_template("_template.qmd")
output = template.render(
    article=article,
)
with open("_output.qmd", "w", encoding="utf-8") as f:
    f.write(output)

# %% [markdown]
# :::: {.callout-note title="Jinja template" collapse=true}
#
# ````{.markdown}
# {{< include _template.qmd >}}
# ````
#
# ::::
#
# :::: {.callout-note title="Template output" collapse=true}
#
# ````{.markdown}
# {{< include _output.qmd >}}
# ````
#
# ::::

# %% [markdown]
# Conclusions:
#
# * It needs more context to be able to create a meaningful discussion.
# * The LLM is not able to reference specific numbers from the highchart properly.
#
# Next steps to try:
#
# * Instead of passing in dataframes, pass in custom objects which describes both the data and context. (e.g. `DataSet("df", df, "This dataset describes ..., has columns ...., and the results are related to ...")`).
# * The output article shouldn't have any data, just references to the input data (e.g. above data would be referenced as `"df"`).
# * Instruct the agent to not put any actual numbers in the text, just placeholders (spans - []).
# * Change `get_article_from_url` to `parse_example_from_url` which shows both the input data and the output article.
# * Try a prompt like: "Example input data:", "Example output article:", "Use this as a model to create a new article based on the following new input data:", "Additional instructions:".
# * Try to drop the sections and have the LLM write the whole article as one string.
# * Try with completely different model articles.
